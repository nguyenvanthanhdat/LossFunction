# %%
# !git clone -b dat https://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@github.com/nguyenvanthanhdat/LossFunction.git
# Out:
# Cloning into 'LossFunction'...
# remote: Enumerating objects: 369, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 369 (delta 46), reused 83 (delta 32), pack-reused 267
# Receiving objects: 100% (369/369), 52.53 KiB | 960.00 KiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
# !ls
# Out:
# LossFunction  sample_data

# %%
# %cd LossFunction/
# Out:
# /content/LossFunction

# %%
# %%capture
# !pip install -r requirements.txt -U

# %%
# !sh scripts/download.sh
# Out:
# LOSS_NLI_DATA not set; downloading to default path ('data').
# Downloading...
# From: https://drive.google.com/uc?id=1EMenaT4KezsGBkbmmKwyaoBBfY4BftcB
# To: /content/LossFunction/data_nli.zip
# 100% 165M/165M [00:01<00:00, 93.3MB/s]
# Download zip file done!
# Unzip file done!
# Download dataset nli done!

# %%
MODEL_NAME_OR_PATH='xlm-roberta-large'
OUTPUT_DIR='output/finetune'
BZ=16


# !python -m src.loss_nli.training \
    --model_name_or_path $MODEL_NAME_OR_PATH \
    --output_dir $OUTPUT_DIR \
    --do_train \
    --train_dir 'data/finetune/train' \
    --valid_dir 'data/finetune/validation' \
    --per_device_train_batch_size $BZ \
    --per_device_train_batch_size $BZ \
    --num_train_epochs 4 \
    --logging_steps 100 \
    --learning_rate 1e-3 \
    --evaluation_strategy 'steps' \
    --loss_func_name 'cross' \
    --overwrite_output_dir \
    --load_best_model_at_end
# Out:
# 2023-12-30 11:28:40.252680: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-30 11:28:40.252734: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-30 11:28:40.254115: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-30 11:28:41.625905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...
